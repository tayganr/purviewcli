# %% [markdown]
# # Relationship

# %%
# Install/Upgrade purviewcli package
# %pip install --upgrade purviewcli

# %%
# Environment Variables
# %env PURVIEW_NAME=YOUR_PURVIEW_ACCOUNT
# %env AZURE_CLIENT_ID=YOUR_CLIENT_ID
# %env AZURE_TENANT_ID=YOUR_TENANT_ID
# %env AZURE_CLIENT_SECRET=YOUR_CLIENT_SECRET

# %%
# Commands
# !pv relationship --help

# %% [markdown]
# ## Create

# %%
# Create
# !pv relationship create --payloadFile "C:\Users\tarifat\Downloads\purviewcli\samples\json\relationship\create.json"

# %% [markdown]
# ## Read

# %%
# Read
# !pv relationship read --guid "adaa22fe-e391-436a-a4c6-dfa3041fcb71"

# %% [markdown]
# ## Update

# %%
# Update
# !pv relationship put --payloadFile "C:\Users\tarifat\Downloads\purviewcli\samples\json\relationship\update.json"

# %% [markdown]
# ## Delete

# %%
# Delete
# !pv relationship delete --guid "adaa22fe-e391-436a-a4c6-dfa3041fcb71"
