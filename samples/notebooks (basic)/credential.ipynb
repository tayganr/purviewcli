# %% [markdown]
# # Credential

# %%
# Install/Upgrade purviewcli package
# %pip install --upgrade purviewcli

# %%
# Environment Variables
# %env PURVIEW_NAME=YOUR_PURVIEW_ACCOUNT
# %env AZURE_CLIENT_ID=YOUR_CLIENT_ID
# %env AZURE_TENANT_ID=YOUR_TENANT_ID
# %env AZURE_CLIENT_SECRET=YOUR_CLIENT_SECRET

# %%
# Commands
# !pv credential --help

# %% [markdown]
# ## Create

# %%
# Create
# !pv credential put --credentialName "dummy" --payloadFile "C:\Users\tarifat\Downloads\purviewcli\samples\json\credential\credential.json"

# %% [markdown]
# ## Read

# %%
# Read
# !pv credential read

# %% [markdown]
# ## Delete

# %%
# Delete
# !pv credential delete --credentialName "dummy"
